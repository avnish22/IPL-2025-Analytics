# %% [markdown]
# <a href="https://colab.research.google.com/github/avnish22/IPL-2025-Analytics/blob/main/IPL_2025_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# libraries

import pandas as pd
import numpy as np

# %%
df_batting = pd.read_csv('/content/batting_modified.csv')

# %%
df_bowling = pd.read_csv('/content/bowling_modified.csv')

# %%
df_batting.shape
# Out:
# (15, 10)

# %%
df_bowling.shape
# Out:
# (15, 9)

# %%
# Add mock StdDev_Runs

np.random.seed(42)
df_batting['StdDev_Runs'] = np.random.uniform(12.0, 25.0, size=len(df_batting))

# %%
# merge two files

df = pd.merge(df_batting, df_bowling, on='Player_Name', how='outer', suffixes=('_Bat', '_Bowl'))

# %%
df.head(1)
# Out:
#        Player_Name Team_Bat  Runs_Bat  Bat_Avg  Bat_SR    4s    6s  50s  \
# 0  Abhishek Sharma      SRH     439.0    33.77  193.39  45.0  28.0  2.0
#
#   Role_Bat  Matches_Bat  StdDev_Runs Team_Bowl  Matches_Bowl  Wkts  Bowl_Eco  \
# 0   Opener         14.0    14.363725       NaN           NaN   NaN       NaN
#
#    Bowl_Avg  Death_Overs_ER Role_Bowl  Runs_Bowl
# 0       NaN             NaN       NaN        NaN

# %%
# clean and finalize columns

df['Runs'] = df['Runs_Bat'].combine_first(df['Runs_Bowl']).fillna(0)
df['Matches'] = df['Matches_Bat'].combine_first(df['Matches_Bowl']).fillna(0)

# %%
df['Wkts'] = df['Wkts'].fillna(0)

# %%
#Combine Role (Prioritizing Batting Role)
df['Role'] = df['Role_Bat'].combine_first(df['Role_Bowl'])

# %%
# Fill remaining NaN values with 0 for metrics/stats
cols_to_fill_zero = df.columns.drop(['Player_Name', 'Role', 'Team_Bat', 'Team_Bowl', 'StdDev_Runs']).tolist()
df[cols_to_fill_zero] = df[cols_to_fill_zero].fillna(0)

# %%
df
# Out:
#             Player_Name Team_Bat  Runs_Bat  Bat_Avg  Bat_SR    4s    6s  50s  \
# 0       Abhishek Sharma      SRH     439.0    33.77  193.39  45.0  28.0  2.0
# 1        Ajinkya Rahane      KKR     289.0    36.12  145.50  32.0  10.0  2.0
# 2        Arshdeep Singh      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 3       Ashutosh Sharma     PBKS     210.0    42.00  198.11  10.0  22.0  0.0
# 4            Axar Patel      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 5         Deepak Chahar      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 6         Hardik Pandya      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 7         Harshal Patel      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 8        Jasprit Bumrah      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 9              KL Rahul       DC     539.0    53.90  149.72  45.0  18.0  3.0
# 10        Krunal Pandya      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 11        Kuldeep Yadav      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 12          Mohsin Khan      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 13    Prabhsimran Singh     PBKS     549.0    32.29  160.52  55.0  30.0  4.0
# 14      Prasidh Krishna      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 15          Rinku Singh      KKR     310.0    38.75  152.00  22.0  18.0  1.0
# 16         Rishabh Pant       DC     388.0    32.33  147.78  35.0  20.0  3.0
# 17          Riyan Parag       RR     393.0    32.75  166.52  30.0  25.0  1.0
# 18        Sai Sudharsan       GT     759.0    54.21  156.17  78.0  20.0  6.0
# 19         Samarth Vyas      CSK     275.0    45.83  140.00  30.0   8.0  2.0
# 20        Shahbaz Ahmed      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 21         Shreyas Iyer     PBKS     604.0    50.33  175.07  58.0  28.0  6.0
# 22         Shubman Gill       GT     650.0    50.00  155.87  62.0  22.0  6.0
# 23     Suryakumar Yadav       MI     717.0    65.18  167.91  65.0  35.0  5.0
# 24          T Natarajan      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 25          Tilak Varma       MI     343.0    31.18  138.30  28.0  15.0  2.0
# 26  Varun Chakaravarthy      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 27           Yash Dayal      NaN       0.0     0.00    0.00   0.0   0.0  0.0
# 28     Yashasvi Jaiswal       RR     559.0    43.00  159.71  68.0  15.0  6.0
# 29     Yuzvendra Chahal      NaN       0.0     0.00    0.00   0.0   0.0  0.0
#
#         Role_Bat  Matches_Bat  ...  Matches_Bowl  Wkts  Bowl_Eco  Bowl_Avg  \
# 0         Opener         14.0  ...           0.0   0.0      0.00      0.00
# 1      Top Order         13.0  ...           0.0   0.0      0.00      0.00
# 2              0          0.0  ...          17.0  21.0      8.88     24.66
# 3       Finisher         13.0  ...           0.0   0.0      0.00      0.00
# 4              0          0.0  ...          14.0  16.0      8.00     25.00
# 5              0          0.0  ...          10.0  12.0      8.55     26.00
# 6              0          0.0  ...          14.0  15.0      9.50     22.80
# 7              0          0.0  ...          13.0  16.0      9.80     25.00
# 8              0          0.0  ...          12.0  18.0      6.67     17.55
# 9      WK-Batter         13.0  ...           0.0   0.0      0.00      0.00
# 10             0          0.0  ...          14.0  11.0      7.45     30.50
# 11             0          0.0  ...          14.0  15.0      7.07     22.10
# 12             0          0.0  ...          10.0  14.0      7.80     21.00
# 13     Opener/WK         17.0  ...           0.0   0.0      0.00      0.00
# 14             0          0.0  ...          15.0  25.0      8.27     19.52
# 15      Finisher         13.0  ...           0.0   0.0      0.00      0.00
# 16     WK-Batter         14.0  ...           0.0   0.0      0.00      0.00
# 17      Finisher         14.0  ...           0.0   0.0      0.00      0.00
# 18     Top Order         15.0  ...           0.0   0.0      0.00      0.00
# 19     Top Order         14.0  ...           0.0   0.0      0.00      0.00
# 20             0          0.0  ...          12.0  10.0      8.00     32.00
# 21  Middle Order         17.0  ...           0.0   0.0      0.00      0.00
# 22     Top Order         15.0  ...           0.0   0.0      0.00      0.00
# 23  Middle Order         16.0  ...           0.0   0.0      0.00      0.00
# 24             0          0.0  ...          12.0  19.0      9.05     20.00
# 25  Middle Order         16.0  ...           0.0   0.0      0.00      0.00
# 26             0          0.0  ...          13.0  17.0      7.66     22.52
# 27             0          0.0  ...          13.0  10.0      9.00     35.10
# 28        Opener         14.0  ...           0.0   0.0      0.00      0.00
# 29             0          0.0  ...          14.0  16.0      9.55     26.87
#
#     Death_Overs_ER       Role_Bowl  Runs_Bowl   Runs  Matches            Role
# 0             0.00               0        0.0  439.0     14.0          Opener
# 1             0.00               0        0.0  289.0     13.0       Top Order
# 2             9.65  Left-arm Pacer       20.0   20.0     17.0  Left-arm Pacer
# 3             0.00               0        0.0  210.0     13.0        Finisher
# 4             8.00     All-Rounder      263.0  263.0     14.0     All-Rounder
# 5             0.00  Right arm pace       35.0   35.0     10.0  Right arm pace
# 6            10.20     All-Rounder      224.0  224.0     14.0     All-Rounder
# 7            10.80  Right arm pace        5.0    5.0     13.0  Right arm pace
# 8             6.48  Right arm pace        0.0    0.0     12.0  Right arm pace
# 9             0.00               0        0.0  539.0     13.0       WK-Batter
# 10            7.20     All-Rounder      180.0  180.0     14.0     All-Rounder
# 11            8.10         Spinner        1.0    1.0     14.0         Spinner
# 12            7.90     All-Rounder       10.0   10.0     10.0     All-Rounder
# 13            0.00               0        0.0  549.0     17.0       Opener/WK
# 14            9.05  Right arm pace        1.0    1.0     15.0  Right arm pace
# 15            0.00               0        0.0  310.0     13.0        Finisher
# 16            0.00               0        0.0  388.0     14.0       WK-Batter
# 17            0.00               0        0.0  393.0     14.0        Finisher
# 18            0.00               0        0.0  759.0     15.0       Top Order
# 19            0.00               0        0.0  275.0     14.0       Top Order
# 20            8.20     All-Rounder      150.0  150.0     12.0     All-Rounder
# 21            0.00               0        0.0  604.0     17.0    Middle Order
# 22            0.00               0        0.0  650.0     15.0       Top Order
# 23            0.00               0        0.0  717.0     16.0    Middle Order
# 24            9.00  Left-arm Pacer        0.0    0.0     12.0  Left-arm Pacer
# 25            0.00               0        0.0  343.0     16.0    Middle Order
# 26            8.50         Spinner        3.0    3.0     13.0         Spinner
# 27            9.55     All-Rounder        5.0    5.0     13.0     All-Rounder
# 28            0.00               0        0.0  559.0     14.0          Opener
# 29           10.05         Spinner        0.0    0.0     14.0         Spinner
#
# [30 rows x 22 columns]

# %%
# --- 2. Phase 2: Metric Generation ---
print("Step 2: Calculating Core Metrics...")
epsilon = 0.001
# Out:
# Step 2: Calculating Core Metrics...

# %%
# 1. Batting Metrics
# Consistency Score = Avg / StdDev (StdDev is mock data)
df['Consistency_Score'] = df['Bat_Avg'] / (df['StdDev_Runs'].fillna(df['Bat_Avg']) + epsilon)
# Batting Value = Avg * sqrt(SR)
df['Batting_Value'] = df['Bat_Avg'] * np.sqrt(df['Bat_SR'].fillna(0))

# %%
# 2. Bowling Metrics
# Control Score = 100 / Death_Overs_ER
df['Control_Score'] = 100 / (df['Death_Overs_ER'].replace(0, np.inf).fillna(np.inf) + epsilon)
# Wicket Threat = Wkts / Matches (Matches is the correct, updated data)
df['Wicket_Threat'] = df['Wkts'] / (df['Matches'].replace(0, np.inf).fillna(np.inf) + epsilon)

# %%
# 3. Normalization and PIR Calculation

print("calculating PIR......")
# Out:
# calculating PIR......

# %%
metrics_cols = ['Consistency_Score', 'Batting_Value', 'Control_Score', 'Wicket_Threat']

# %%
def normalize_column(series):
  min_val, max_val = series.min(), series.max()
  if max_val == min_val: return series
  return (series - min_val) / (max_val - min_val)

# %%
for col in metrics_cols:
  df[f'Norm_{col}'] = normalize_column(df[col])

# %%
# Calculate PIRs (Weight: 60% Consistency/Control, 40% Value/Threat)
df['Batting_PIR'] = (0.6 * df['Norm_Consistency_Score']) + (0.4 * df['Norm_Batting_Value'])
df['Bowling_PIR'] = (0.6 * df['Norm_Control_Score']) + (0.4 * df['Norm_Wicket_Threat'])
df['Final_PIR'] = df[['Batting_PIR', 'Bowling_PIR']].max(axis=1)

# %%
# All-Rounder Rule: PIR is the average of Batting PIR and Bowling PIR
is_all_rounder = (df['Runs'] > 0) & (df['Wkts'] > 0)
df.loc[is_all_rounder, 'Final_PIR'] = (df['Batting_PIR'] + df['Bowling_PIR']) / 2

# %%
# ---- final output
final_columns = ['Player_Name', 'Role', 'Runs', 'Wkts', 'Matches', 'Final_PIR','Norm_Consistency_Score', 'Norm_Batting_Value', 'Norm_Control_Score', 'Norm_Wicket_Threat']
df_final = df[final_columns].sort_values(by='Final_PIR', ascending=False)
csv_file_path = 'IPL_2026_Selector_Metrics_Final.csv'
df_final.to_csv(csv_file_path, index=False)

# %%
print("\n--- Final Player Impact Rating (PIR) Rank (Top 10) ---")
print(df_final.head(10))
print(f"\n✅ All analysis complete. Final file saved: {csv_file_path}")
# Out:
# --- Final Player Impact Rating (PIR) Rank (Top 10) ---
#          Player_Name            Role   Runs  Wkts  Matches  Final_PIR  \
# 8     Jasprit Bumrah  Right arm pace    0.0  18.0     12.0   0.959994
# 9           KL Rahul       WK-Batter  539.0   0.0     13.0   0.912346
# 18     Sai Sudharsan       Top Order  759.0   0.0     15.0   0.822661
# 23  Suryakumar Yadav    Middle Order  717.0   0.0     16.0   0.817849
# 24       T Natarajan  Left-arm Pacer    0.0  19.0     12.0   0.812012
# 28  Yashasvi Jaiswal          Opener  559.0   0.0     14.0   0.736014
# 3    Ashutosh Sharma        Finisher  210.0   0.0     13.0   0.724302
# 15       Rinku Singh        Finisher  310.0   0.0     13.0   0.719503
# 21      Shreyas Iyer    Middle Order  604.0   0.0     17.0   0.712676
# 29  Yuzvendra Chahal         Spinner    0.0  16.0     14.0   0.661171
#
#     Norm_Consistency_Score  Norm_Batting_Value  Norm_Control_Score  \
# 8                 0.000000            0.000000            1.000000
# 9                 1.000000            0.780865            0.000000
# 18                0.836372            0.802095            0.000000
# 23                0.696414            1.000000            0.000000
# 24                0.000000            0.000000            0.720031
# 28                0.797756            0.643401            0.000000
# 3                 0.740555            0.699922            0.000000
# 15                0.822077            0.565641            0.000000
# 21                0.662153            0.788461            0.000000
# 29                0.000000            0.000000            0.644811
#
#     Norm_Wicket_Threat
# 8             0.899985
# 9             0.000000
# 18            0.000000
# 23            0.000000
# 24            0.949984
# 28            0.000000
# 3             0.000000
# 15            0.000000
# 21            0.000000
# 29            0.685711
#
# ✅ All analysis complete. Final file saved: IPL_2026_Selector_Metrics_Final.csv
